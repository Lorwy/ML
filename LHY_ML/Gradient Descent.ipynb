# %% [markdown]
# # Adaptive Learning Rates
#
# - Popular & Simple Idea: Reduce the learning rate by some factor every few epochs.
#    - At the beginning , we are far from the destination, so we user large learning rate.
#
#     **刚开始要大点**
#
#    - After several epochs, we are close to the destination, so we reduce the learning rate
#
#     **此时需要的就要小点**
#
#    - E.g. 1/t decay: α = α / √￣(t+1)
#
# - Learning rate cannot be one-size-fits-all
#    - Giving different parameters different learning rates.
#
#
# # Adagrad
#    - Divide the learning rate of each parameter by the root mean square of its previous derivatives
#     ![image.png](attachment:image.png)
#
# # Adam
# 现在比较稳定的，而且不会像Adagrad后期会更新得越来越慢
#
#
#
# # Stochastic Gradient Descent（随机初始化）
# 每次只拿一个x出来
#
# # Feature Scaling（特征缩放）
#
#    做了特征缩放是有加速梯度下降的效果的，因为下降方向基本上是直奔低点方向去的
#
#    ![WechatIMG270.jpeg](attachment:WechatIMG270.jpeg)
